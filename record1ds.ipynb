# %%
a=int(input("enter first num"))
b=int(input("enter second num"))
print("Addition=",a+b)
print("Substraction=",a-b)
print("division=",a/b)
# Out:
# enter first num 5
# enter second num 6
# Addition= 11
# Substraction= -1
# division= 0.8333333333333334

# %%
str1=input("enter first num")
str2=input("enter second num")
str3=str1+""+str2
print("concat string:",str3)
# Out:
# enter first num hello
# enter second num world
# concat string: helloworld

# %%
str1=input("enter first num")
str2=input("enter second num")
str3=str1+""+str2
print("concat string:",str3)
print("uppercase:",str1.upper())
print("lowercase:",str2.lower())
print("length of str3",len(str3))
# Out:
# enter first num hello
# enter second num pythom
# concat string: hellopythom
# uppercase: HELLO
# lowercase: pythom
# length of str3 11

# %%
color=input("enter different color:")
list=list(color.split(","))
print(list)
print("last color:",list[-1])
print("first color:",list[0])

clr=input("enter color to append:")
list.append(clr)
print("Append list:",list)

clr1=input("enter color to remove:")
list.remove(clr1)
print("Removed list:",list)

newclr=input("enter new color to replace in second position:")
list[1]=newclr
print("updated list:",list)
# Out:
# enter different color: pink,yellow,white
# ['pink', 'yellow', 'white']
# last color: white
# first color: pink
# enter color to append: blue
# Append list: ['pink', 'yellow', 'white', 'blue']
# enter color to remove: yellow
# Removed list: ['pink', 'white', 'blue']
# enter new color to replace in second position: blue
# updated list: ['pink', 'blue', 'blue']

# %%
n=int(input("enter the number:"))
for i in range(5):
    print(i)
# Out:
# enter the number: 5
# 0
# 1
# 2
# 3
# 4

# %%
student={
    "name": "anu",
    "age":20,
    "course": "mca"
} 
print(student)
# Out:
# {'name': 'anu', 'age': 20, 'course': 'mca'}

# %%
s=set(map(int,input("enter number:").split()))
print(s)
# Out:
# enter number: 12
# {12}

# %%
t=tuple(map(int,input("enter number:").split()))
print(t)
# Out:
# enter number: 13 20
# (13, 20)

# %%
def sum(a,b):
    print(a+b)
    great(4,8)

# %%
#largest number from list
numbers = list(map(int,input("Enter the numbers").split()))
largest = max(numbers)
print("Largest number:",largest)
# Out:
# Enter the numbers 4 5 6
# Largest number: 6

# %%
#remove duplicate
numbers=[1,2,2,3,3,4,4,5]
unique=list(set(numbers))
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
# c convert tuple to dict
keys = ("aju", "manu", "vinu")
values = (21, 22, 23)

d = dict(zip(keys, values))

print(d)
# Out:
# {'aju': 21, 'manu': 22, 'vinu': 23}

# %%
# d dict
Rno=input("Enter the roll number for 3 students [using space]:").split()
Rno1=list(map(int,Rno))
names=input("Enter 3 students names [using space]:").split()

students=dict(zip(Rno,names))
print("Students with Roll_numbers:",students)

Rno2=input("Enter the roll number for 2 students:").split()
Rno3=list(map(int,Rno))
names1=input("Enter 2 students names:").split()

students1=dict(zip(Rno3,names1))
print("Students with Roll_numbers:",students1)

students.update(students1)
print("Merged dictionary:",students)
# Out:
# Enter the roll number for 3 students [using space]: 2 3 4
# Enter 3 students names [using space]: anu karu vinu
# Students with Roll_numbers: {'2': 'anu', '3': 'karu', '4': 'vinu'}
# Enter the roll number for 2 students: 4 7
# Enter 2 students names: allen maya
# Students with Roll_numbers: {2: 'allen', 3: 'maya'}
# Merged dictionary: {'2': 'anu', '3': 'karu', '4': 'vinu', 2: 'allen', 3: 'maya'}
